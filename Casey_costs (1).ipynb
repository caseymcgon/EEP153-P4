# %% [markdown]
# ## Costs

# %% [markdown]
# ### Preface

# %% [markdown]
# There are a few modules you may need to install:

# %%
# !pip install CFEDemands --upgrade
# !pip install xarray
# !pip install dvc[gdrive]
# !pip install h5netcdf
# Out:
# Collecting CFEDemands
#   Using cached CFEDemands-0.2.9-py2.py3-none-any.whl (36 kB)
# Installing collected packages: CFEDemands
# Successfully installed CFEDemands-0.2.9
# Requirement already satisfied: xarray in /opt/conda/lib/python3.8/site-packages (0.16.2)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.8/site-packages (from xarray) (1.19.5)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.8/site-packages (from xarray) (1.2.0)
# Requirement already satisfied: setuptools>=38.4 in /opt/conda/lib/python3.8/site-packages (from xarray) (56.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.25->xarray) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.25->xarray) (2020.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->xarray) (1.15.0)
# Collecting dvc[gdrive]
#   Using cached dvc-2.0.18-py2.py3-none-any.whl (633 kB)
# Collecting rich>=10.0.0
#   Using cached rich-10.1.0-py3-none-any.whl (201 kB)
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Collecting zc.lockfile>=1.2.1
#   Using cached zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting tabulate>=0.8.7
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting voluptuous>=0.11.7
#   Using cached voluptuous-0.12.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (2.5)
# Collecting dictdiffer>=0.8.1
#   Using cached dictdiffer-0.8.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests>=2.22.0 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (2.25.1)
# Collecting gitpython>3
#   Using cached GitPython-3.1.14-py3-none-any.whl (159 kB)
# Processing /home/jovyan/.cache/pip/wheels/0f/1b/ca/6263a5227f886599039aee3eed13951a6d44a02ee989ed6eb6/dpath-2.0.1-py3-none-any.whl
# Requirement already satisfied: pyasn1>=0.4.1 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (0.4.8)
# Requirement already satisfied: colorama>=0.3.9 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (0.4.3)
# Collecting dulwich>=0.20.21
#   Using cached dulwich-0.20.21-cp38-cp38-manylinux2010_x86_64.whl (516 kB)
# Collecting grandalf==0.6
#   Using cached grandalf-0.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: toml>=0.10.1 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (0.10.2)
# Collecting python-benedict>=0.21.1
#   Using cached python_benedict-0.23.2-py3-none-any.whl (39 kB)
# Collecting diskcache>=5.2.1
#   Using cached diskcache-5.2.1-py3-none-any.whl (44 kB)
# Collecting fsspec==0.9.0
#   Using cached fsspec-0.9.0-py3-none-any.whl (107 kB)
# Collecting funcy>=1.14
#   Using cached funcy-1.15-py2.py3-none-any.whl (32 kB)
# Collecting jsonpath-ng>=1.5.1
#   Using cached jsonpath_ng-1.5.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (5.8.0)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (1.4.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (3.7.4.3)
# Processing /home/jovyan/.cache/pip/wheels/59/72/23/ea2daa0727a9f7824c0656b73c1f3d8d13f5327729eadb7084/nanotime-0.5.2-py3-none-any.whl
# Processing /home/jovyan/.cache/pip/wheels/bc/7d/26/d3e5714967aa183b5c659493fa88daf270295948d0ac277686/pygtrie-2.3.2-py3-none-any.whl
# Processing /home/jovyan/.cache/pip/wheels/f4/f4/20/d7114a2d97a2e72ce7189a7f63a6fbd2a33ec6ae6010befca5/flufl.lock-3.2-py3-none-any.whl
# Requirement already satisfied: ruamel.yaml>=0.16.1 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (0.17.4)
# Collecting flatten-dict<1,>=0.3.0
#   Using cached flatten_dict-0.3.0-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: packaging>=19.0 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (20.9)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (2.4.7)
# Requirement already satisfied: distro>=1.3.0 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (1.5.0)
# Collecting shtab<2,>=1.3.4
#   Using cached shtab-1.3.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pydot>=1.2.4 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (1.4.1)
# Requirement already satisfied: setuptools>=34.0.0 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (56.0.0)
# Collecting ply>=3.9
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Collecting pathspec>=0.6.0
#   Using cached pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: tqdm<5,>=4.45.0 in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (4.56.0)
# Processing /home/jovyan/.cache/pip/wheels/34/2a/24/a490264ae9041fd48f778ff393526572c80bb498ddecb07ea5/configobj-5.0.6-py3-none-any.whl
# Collecting pygit2>=1.5.0
#   Using cached pygit2-1.5.0-cp38-cp38-manylinux2014_x86_64.whl (3.1 MB)
# Collecting pydrive2>=1.8.1; extra == "gdrive"
#   Using cached PyDrive2-1.8.2-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: six>=1.13.0; extra == "gdrive" in /opt/conda/lib/python3.8/site-packages (from dvc[gdrive]) (1.15.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/conda/lib/python3.8/site-packages (from rich>=10.0.0->dvc[gdrive]) (2.8.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.8/site-packages (from networkx>=2.1->dvc[gdrive]) (4.4.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.22.0->dvc[gdrive]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.22.0->dvc[gdrive]) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.22.0->dvc[gdrive]) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.22.0->dvc[gdrive]) (1.25.7)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.7-py3-none-any.whl (63 kB)
# Requirement already satisfied: future in /opt/conda/lib/python3.8/site-packages (from grandalf==0.6->dvc[gdrive]) (0.18.2)
# Processing /home/jovyan/.cache/pip/wheels/ea/fd/82/b600967fbbe79767c7bfef97cd5f82bf26c4e6d96a98260d4d/ftfy-6.0.1-py3-none-any.whl
# Collecting python-fsutil
#   Using cached python_fsutil-0.4.0-py3-none-any.whl (11 kB)
# Collecting phonenumbers
#   Using cached phonenumbers-8.12.21-py2.py3-none-any.whl (2.6 MB)
# Collecting xmltodict
#   Using cached xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.8/site-packages (from python-benedict>=0.21.1->dvc[gdrive]) (2.8.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.8/site-packages (from python-benedict>=0.21.1->dvc[gdrive]) (5.4.1)
# Processing /home/jovyan/.cache/pip/wheels/63/0d/30/bffc322c684cf05dcd59e85c244b25bb56f6a3e86753c50e70/mailchecker-4.0.6-py3-none-any.whl
# Requirement already satisfied: python-slugify in /opt/conda/lib/python3.8/site-packages (from python-benedict>=0.21.1->dvc[gdrive]) (4.0.1)
# Processing /home/jovyan/.cache/pip/wheels/f3/a4/10/e7e5bb869828997204dc4a7ce0760132c7d6d5ae47a5e58b90/atpublic-2.3-py3-none-any.whl
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in /opt/conda/lib/python3.8/site-packages (from ruamel.yaml>=0.16.1->dvc[gdrive]) (0.2.2)
# Collecting pathlib2<3.0,>=2.3
#   Using cached pathlib2-2.3.5-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: cffi>=1.4.0 in /opt/conda/lib/python3.8/site-packages (from pygit2>=1.5.0->dvc[gdrive]) (1.14.5)
# Collecting cached-property
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: google-api-python-client>=1.12.5 in /opt/conda/lib/python3.8/site-packages (from pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (1.12.8)
# Collecting oauth2client>=4.0.0
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: pyOpenSSL>=19.1.0 in /opt/conda/lib/python3.8/site-packages (from pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (19.1.0)
# Collecting smmap<5,>=3.0.1
#   Using cached smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from ftfy; python_version > "2.7"->python-benedict>=0.21.1->dvc[gdrive]) (0.2.5)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/conda/lib/python3.8/site-packages (from python-slugify->python-benedict>=0.21.1->dvc[gdrive]) (1.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.4.0->pygit2>=1.5.0->dvc[gdrive]) (2.20)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (0.19.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (3.0.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (1.26.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (0.0.4)
# Requirement already satisfied: google-auth>=1.16.0 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (1.29.0)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from oauth2client>=4.0.0->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /opt/conda/lib/python3.8/site-packages (from oauth2client>=4.0.0->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (0.2.8)
# Requirement already satisfied: cryptography>=2.8 in /opt/conda/lib/python3.8/site-packages (from pyOpenSSL>=19.1.0->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (3.4.7)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (1.53.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.8/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (2020.5)
# Requirement already satisfied: protobuf>=3.12.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (3.15.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth>=1.16.0->google-api-python-client>=1.12.5->pydrive2>=1.8.1; extra == "gdrive"->dvc[gdrive]) (4.2.1)
# Installing collected packages: commonmark, rich, shortuuid, zc.lockfile, tabulate, voluptuous, dictdiffer, smmap, gitdb, gitpython, dpath, dulwich, grandalf, ftfy, python-fsutil, phonenumbers, xmltodict, mailchecker, python-benedict, diskcache, fsspec, funcy, ply, jsonpath-ng, nanotime, pygtrie, atpublic, flufl.lock, pathlib2, flatten-dict, shtab, pathspec, configobj, cached-property, pygit2, oauth2client, pydrive2, dvc
# Successfully installed atpublic-2.3 cached-property-1.5.2 commonmark-0.9.1 configobj-5.0.6 dictdiffer-0.8.1 diskcache-5.2.1 dpath-2.0.1 dulwich-0.20.21 dvc-2.0.18 flatten-dict-0.3.0 flufl.lock-3.2 fsspec-0.9.0 ftfy-6.0.1 funcy-1.15 gitdb-4.0.7 gitpython-3.1.14 grandalf-0.6 jsonpath-ng-1.5.2 mailchecker-4.0.6 nanotime-0.5.2 oauth2client-4.1.3 pathlib2-2.3.5 pathspec-0.8.1 phonenumbers-8.12.21 ply-3.11 pydrive2-1.8.2 pygit2-1.5.0 pygtrie-2.3.2 python-benedict-0.23.2 python-fsutil-0.4.0 rich-10.1.0 shortuuid-1.0.1 shtab-1.3.5 smmap-4.0.0 tabulate-0.8.9 voluptuous-0.12.1 xmltodict-0.12.0 zc.lockfile-2.0
# Collecting h5netcdf
#   Using cached h5netcdf-0.11.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.8/site-packages (from h5netcdf) (3.1.0)
# Requirement already satisfied: numpy>=1.17.5; python_version == "3.8" in /opt/conda/lib/python3.8/site-packages (from h5py->h5netcdf) (1.19.5)
# Installing collected packages: h5netcdf
# Successfully installed h5netcdf-0.11.0

# %% [markdown]
# All the data required for estimation and calculation can be found
#    in a google spreadsheet.  Choose one to explore!

# %%
COUNTRY = 'Uganda'

# %%
URL = {'Uganda':'https://docs.google.com/spreadsheets/d/1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ/',
       'Tanzania':'https://docs.google.com/spreadsheets/d/1Tknc2F8K6SaA7j0R7J_NE8yJBTsCPPw77_Bfc04MY40/',
       'ICRISAT':'https://docs.google.com/spreadsheets/d/13Ig5hZif-NSHtgkKRp_cEgKXk0lOsdUB2BAD6O_FnRo'}
DAYS_PER_PERIOD = {'Uganda':7,'Tanzania':7,'ICRISAT':365.25} # Number of days of expenditure recall

# %% [markdown]
# To read the various sheets, we&rsquo;ll need some credentials.  Import a
#  function to read google sheets, and point to an
#  unencrypted json file that has the appropriate permissions:

# %%
## If running from the class jupyterhub (in Project 4 folder)

## If this breaks, uncomment and run the next cell!

from eep153_tools import read_sheets

my_creds = '../students.json'

# %%
## ##If running after downloading from GITHUB

## ##PASSPHRASE --> passphrase we've been running in class
## from eep153_tools import read_sheets

## !pip install oauth2client
## !gpg --batch --passphrase "PASSPHRASE" -d ../students.json.gpg > ../students.json

## my_creds = '../students.json'

## ##if next cell doesn't run, change my_creds to this:
## my_creds = 'students.json.gpg'

# %% [markdown]
# ### Estimation

# %% [markdown]
# First, we pull in data and estimate CFE demands *given* the prices
#     and budgets of households in the data.

# %%
import cfe
import numpy as np
from eep153_tools import read_sheets

x = read_sheets(URL[COUNTRY],json_creds=my_creds,sheet='Expenditures').set_index(['j','t','m'])
x.columns.name = 'i'
x = x.replace(0,np.nan)
y = np.log(x)

z = read_sheets(URL[COUNTRY],json_creds=my_creds,sheet='HH Characteristics').set_index(['j','t','m'])
z.columns.name = 'k'

p = read_sheets(URL[COUNTRY],json_creds=my_creds,sheet='Prices').set_index(['t','m'])
p.columns.name = 'i'

r = cfe.Result(y=y,z=z,prices=p)

r.get_alpha()
xhat = r.get_predicted_expenditures()
# Out:
# /opt/conda/lib/python3.8/site-packages/xarray/core/nputils.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)

# %% [markdown]
# Estimation is kind of expensive, so you might want to save these
#  results to use in your later code.

# %%
r.to_dataset("my %s.ds" % COUNTRY)
# Out:
# /opt/conda/lib/python3.8/site-packages/h5netcdf/core.py:769: FutureWarning: String decoding changed with h5py >= 3.0. See https://docs.h5py.org/en/latest/strings.html for more details. Currently backwards compatibility with h5py < 3.0 is kept by decoding vlen strings per default. This will change in future versions for consistency with h5py >= 3.0. To silence this warning set kwarg ``decode_vlen_strings=False``. Setting ``decode_vlen_strings=True`` forces vlen string decoding.
#   warnings.warn(msg, FutureWarning, stacklevel=0)
# <xarray.Dataset>
# Dimensions:           (i: 51, j: 10159, k: 15, kp: 15, m: 1, t: 6)
# Coordinates:
#   * j                 (j) object '1013000201' '1013000202' ... 'H4301001'
#   * i                 (i) object 'Beans' 'Beef' ... 'Water' 'Wheat (flour)'
#   * k                 (k) object 'F 00-03' 'M 00-03' ... 'M 51+' 'log HSize'
#   * t                 (t) object '2005-06' '2009-10' ... '2013-14' '2015-16'
#   * m                 (m) object 'Uganda'
#   * kp                (kp) <U9 'F 00-03' 'F 04-08' ... 'M 51+' 'log HSize'
# Data variables:
#     alpha             (i) float64 6.538 7.501 8.361 6.426 ... 5.816 nan nan
#     beta              (i) float64 0.2344 0.3721 0.5759 0.6146 ... 0.462 nan nan
#     delta             (k, i) float64 -0.018 -0.02526 -0.01543 ... nan nan
#     prices            (i, t, m) float64 600.0 1.25e+03 ... 2.5e+03 2.7e+03
#     characteristics   (k, j, t, m) float64 0.0 0.0 0.0 0.0 ... nan nan nan 1.946
#     loglambdas        (j, t, m) float64 -1.233 0.01116 -0.6326 ... nan -0.4518
#     a                 (i, t, m) float64 6.538 7.082 7.292 7.389 ... nan nan nan
#     yhat              (j, t, m, i) float64 6.88 8.041 9.117 ... 7.259 nan nan
#     ce                (j, t, m, i) float64 nan 1.118 -0.6234 ... -0.8352 nan nan
#     cehat             (j, t, m, i) float64 0.2891 0.4588 0.7102 ... nan nan
#     e                 (i, j, m, t) float64 nan nan nan nan ... nan nan nan nan
#     delta_covariance  (i, k, kp) float64 0.0001698 2.553e-05 ... nan nan
#     beta_covariance   object None
#     se_delta          (i, k) float64 0.01303 0.01329 0.01108 ... nan nan nan
#     se_beta           object None
#     se_alpha          (i) float64 0.01585 0.01851 0.07667 ... 0.01593 0.0 0.0
#     se_a              (i, t, m) float64 0.01585 0.01713 0.0173 ... nan nan nan
#     y                 (i, j, m, t) float64 nan nan nan nan ... nan nan nan nan
#     logp              (i, t, m) float64 6.397 7.131 7.313 ... nan 7.824 7.901
#     z                 (k, j, t, m) float64 0.0 0.0 0.0 0.0 ... nan nan nan 1.946

# %% [markdown]
# By the same token, if you&rsquo;ve **already** saved the estimated result, you
#  can skip estimation and just  load it&#x2026;

# %%
import cfe
r = cfe.from_dataset("my %s.ds" % COUNTRY)

# %% [markdown]
# 𝛼  (bigger alpha = larger budget share)

# %%
r.get_alpha(as_df=True)
# Out:
# i
# Beans             6.537682
# Beef              7.500638
# Beer              8.360626
# Bun               6.425699
# Cabbages          5.882989
# Cassava           6.592677
# Chicken           8.063880
# Cigarettes        6.813737
# Coffee            4.628108
# Cooking oil       5.962613
# Dodo              5.574761
# Dried fish        6.520910
# Eggs              6.182399
# Fresh fish        7.015686
# Fresh milk        6.832323
# Goat meat         7.277119
# Ground nut        6.229871
# Irish potato      6.807111
# Maize             6.619745
# Mangos            6.009520
# Matoke            7.386895
# Millet            6.335612
# Onions            4.994139
# Oranges           5.658361
# Other Alcohol     6.883310
# Other Fruit       6.053041
# Other Tobacco     5.445785
# Other Veg.        5.579663
# Other foods       6.864447
# Passion fruit     6.241966
# Peas              6.197789
# Pork              7.083545
# Restaurant        8.074264
# Rice              6.708283
# Salt              4.233558
# Sim sim           6.166700
# Soda              7.077052
# Sorghum           5.985787
# Sugar             6.644518
# Sweet Banana      5.773295
# Sweet Potatoes    6.721145
# Tea               4.522477
# Tomatoes          5.816340
# Name: alpha, dtype: float64

# %% [markdown]
# (higher beta = spend more on it as you get wealthier)

# %%
r.get_beta(as_df=True).dropna()
# Out:
# i
# Beans             0.234401
# Beef              0.372068
# Beer              0.575916
# Bun               0.614612
# Cabbages          0.302597
# Cassava           0.100006
# Chicken           0.324125
# Cigarettes        0.533225
# Coffee            0.655771
# Cooking oil       0.454043
# Dodo              0.337421
# Dried fish        0.337026
# Eggs              0.454384
# Fresh fish        0.387190
# Fresh milk        0.570633
# Goat meat         0.377250
# Ground nut        0.310636
# Irish potato      0.320683
# Maize             0.248386
# Mangos            0.396619
# Matoke            0.438673
# Millet            0.195983
# Onions            0.423031
# Oranges           0.560503
# Other Alcohol     0.424832
# Other Fruit       0.575993
# Other Tobacco     0.497631
# Other Veg.        0.439217
# Other foods       0.709945
# Passion fruit     0.689185
# Peas              0.353778
# Pork              0.352783
# Restaurant        0.566696
# Rice              0.391052
# Salt              0.108925
# Sim sim           0.206310
# Soda              0.512992
# Sorghum           0.275993
# Sugar             0.412710
# Sweet Banana      0.558044
# Sweet Potatoes    0.179885
# Tea               0.297064
# Tomatoes          0.462044
# Name: beta, dtype: float64

# %% [markdown]
# (delta: for every additional 14-18 y.o. female, we expect a 0.063125 increase in spending on 'Cabbages')

# %%
r.delta.to_dataframe().unstack('k').dropna()
# Out:
#                    delta                                                    \
# k                F 00-03   F 04-08   F 09-13   F 14-18   F 19-30   F 31-50
# i
# Beans          -0.017999  0.034981  0.052855  0.063154  0.023157  0.052992
# Beef           -0.025260  0.019889  0.035193  0.044315  0.111598  0.081288
# Beer           -0.015431 -0.036532  0.018052  0.074591  0.131731  0.046029
# Bun            -0.087353 -0.006391  0.040575  0.091875  0.160765  0.083337
# Cabbages       -0.003930 -0.009994  0.037094  0.063125  0.049393  0.027506
# Cassava         0.004183  0.065387  0.056505  0.078548 -0.045982  0.002342
# Chicken        -0.039953  0.015808  0.022267  0.014636  0.104601  0.057266
# Cigarettes     -0.025908  0.015616  0.083046  0.116204  0.160765  0.088711
# Coffee         -0.027479  0.086817  0.002732  0.109072  0.166417  0.178985
# Cooking oil    -0.052017 -0.025481  0.012932  0.077885  0.138742  0.018563
# Dodo           -0.002092  0.009070  0.054516  0.009381  0.060706  0.111837
# Dried fish     -0.007132  0.021437  0.034846  0.036524  0.125292  0.057210
# Eggs           -0.111515 -0.005256  0.014971  0.029990  0.113263  0.003769
# Fresh fish     -0.005652 -0.004744  0.042384  0.071407  0.086152  0.047757
# Fresh milk      0.038668 -0.040441 -0.009191  0.043499  0.124750  0.055483
# Goat meat      -0.009948  0.057223  0.023939  0.048050  0.086131  0.083003
# Ground nut     -0.015400  0.032595  0.053178  0.076803  0.092084  0.138688
# Irish potato   -0.028844  0.026367  0.104731  0.055365 -0.020372  0.049677
# Maize           0.048070  0.090715  0.116153  0.066806  0.003468  0.038234
# Mangos         -0.002556 -0.020819 -0.022345  0.014498 -0.038583 -0.047458
# Matoke         -0.028418  0.016977  0.025365  0.061394  0.094764  0.064267
# Millet          0.003166  0.008477  0.031641  0.040993 -0.021391  0.010887
# Onions         -0.073857 -0.036582  0.008960  0.057534  0.152761  0.071199
# Oranges        -0.044841  0.043257 -0.007226  0.118968  0.168256  0.036286
# Other Alcohol  -0.093747 -0.013331 -0.020351  0.070077  0.117530  0.070451
# Other Fruit    -0.008104  0.022932  0.027286  0.023663  0.096108  0.064138
# Other Tobacco  -0.079231  0.012811  0.046680  0.099380  0.182294 -0.016814
# Other Veg.     -0.014914  0.011129  0.017122  0.033280  0.074101  0.114974
# Other foods     0.012370 -0.008227  0.029583  0.058048  0.223057  0.256621
# Passion fruit  -0.032325 -0.038923 -0.028887  0.062640  0.150987  0.198311
# Peas           -0.026376 -0.023970  0.016232  0.045119  0.028415  0.044640
# Pork           -0.053361  0.007876  0.032283  0.043560  0.095754  0.097909
# Restaurant     -0.136361 -0.038271  0.038828  0.068996  0.228282  0.109589
# Rice           -0.008266  0.048031  0.051108  0.068813  0.090732  0.017859
# Salt            0.010307  0.020341  0.033765  0.039208  0.016516  0.027499
# Sim sim        -0.006530 -0.011156  0.006429  0.056201  0.031903  0.007107
# Soda           -0.049268 -0.055025  0.073619  0.079079  0.150167  0.011735
# Sorghum        -0.105442 -0.072370 -0.004487 -0.036668 -0.070149 -0.027391
# Sugar          -0.026405  0.008981  0.034377  0.067575  0.133521  0.097303
# Sweet Banana   -0.031568 -0.039908 -0.006773  0.070470  0.079022  0.090499
# Sweet Potatoes  0.016238  0.098942  0.085182  0.075454  0.001702  0.049116
# Tea            -0.022437  0.019902  0.026469  0.064690  0.123288  0.129120
# Tomatoes       -0.037621 -0.012002  0.020229  0.060092  0.166797  0.073032
#
#                                                                             \
# k                  F 51+   M 00-03   M 04-08   M 09-13   M 14-18   M 19-30
# i
# Beans           0.082714 -0.019997  0.025129  0.067315  0.071476  0.066831
# Beef            0.049441 -0.019040  0.017515  0.047792  0.052201  0.102283
# Beer           -0.083552 -0.037448 -0.056217  0.067258  0.021468  0.154906
# Bun             0.045677 -0.043017 -0.022244  0.014229  0.036367  0.112226
# Cabbages        0.034540 -0.020378 -0.020097  0.027214  0.046406  0.055729
# Cassava         0.055244  0.002645  0.083604  0.098783  0.103278  0.058395
# Chicken         0.029128 -0.035256 -0.003141 -0.018970  0.044561  0.103837
# Cigarettes      0.014699 -0.063922  0.113987  0.059124  0.005431  0.204197
# Coffee          0.139521  0.027863  0.033373  0.053016  0.024063  0.132334
# Cooking oil    -0.083335 -0.042827 -0.040402 -0.004322  0.024322  0.103512
# Dodo            0.130844  0.001183  0.042759  0.108621  0.055486  0.046950
# Dried fish      0.046564 -0.034193  0.010934  0.043176  0.081867  0.116108
# Eggs            0.056728 -0.040928  0.022695 -0.007691  0.038312  0.074656
# Fresh fish      0.012861 -0.016875  0.047308  0.008839  0.041892  0.101411
# Fresh milk      0.101769  0.006766 -0.017075 -0.002797  0.056000  0.118067
# Goat meat       0.125642 -0.031334  0.037727  0.002169  0.095330  0.122832
# Ground nut      0.171367  0.014885  0.044799  0.055597  0.046600  0.082004
# Irish potato    0.167443  0.069238  0.104606  0.134742  0.054475  0.062422
# Maize           0.125249  0.038393  0.047528  0.106549  0.076685  0.057489
# Mangos         -0.011715 -0.048436  0.013212  0.032423  0.032323  0.053955
# Matoke          0.121904 -0.063157  0.018634  0.021329  0.054952  0.064061
# Millet          0.216018  0.002094  0.024802  0.024919  0.085212  0.046495
# Onions         -0.018530 -0.066738 -0.032100 -0.009403  0.014696  0.077044
# Oranges         0.051614 -0.003362  0.108533  0.042115  0.069034  0.118094
# Other Alcohol  -0.006324 -0.073196  0.021273 -0.022924  0.090913  0.066244
# Other Fruit     0.053109 -0.045404  0.051983  0.111805  0.057857  0.081559
# Other Tobacco   0.142317 -0.059524  0.091704  0.094636  0.007318 -0.006790
# Other Veg.      0.164908 -0.018256  0.056522  0.048217  0.027537  0.064058
# Other foods     0.064969 -0.105676 -0.098526  0.126961  0.031454  0.026598
# Passion fruit   0.065780 -0.021104 -0.038386 -0.030652 -0.080409  0.039512
# Peas            0.028447 -0.062569 -0.004245  0.059109  0.041287  0.039118
# Pork            0.064638 -0.062371 -0.025853  0.058846  0.067855  0.080515
# Restaurant     -0.135695 -0.110116 -0.047448  0.022121  0.054151  0.189300
# Rice            0.073958 -0.010510  0.018254  0.067770  0.083412  0.085811
# Salt            0.061614  0.024054  0.020422  0.032349  0.044799  0.031792
# Sim sim         0.088229 -0.004682  0.054149 -0.058446  0.081087  0.074146
# Soda           -0.129278 -0.016470 -0.065570  0.005283 -0.009306  0.102436
# Sorghum         0.030760  0.031807 -0.016549 -0.020145  0.019863 -0.076867
# Sugar           0.070675 -0.023338  0.011660  0.020004  0.052155  0.084348
# Sweet Banana    0.091417 -0.091101  0.000858 -0.017748  0.034720  0.092888
# Sweet Potatoes  0.121364  0.044871  0.091506  0.112549  0.102182  0.034877
# Tea             0.129527 -0.015441  0.011493  0.013358  0.034368  0.106799
# Tomatoes       -0.004911 -0.045420 -0.030099  0.004401  0.027517  0.084472
#
#
# k                M 31-50     M 51+ log HSize
# i
# Beans           0.076857  0.134526  0.283114
# Beef            0.161847  0.155992  0.123768
# Beer            0.352466  0.168027 -0.142948
# Bun             0.221019  0.103865  0.145853
# Cabbages        0.029333  0.071185  0.166806
# Cassava         0.032107  0.067405  0.261606
# Chicken         0.117374  0.120812  0.033088
# Cigarettes      0.299018  0.157862 -0.178141
# Coffee          0.183878  0.405479 -0.165573
# Cooking oil     0.120263  0.034877  0.155855
# Dodo            0.039222  0.133781  0.092562
# Dried fish      0.207113  0.152007  0.070959
# Eggs            0.178600  0.114862  0.093648
# Fresh fish      0.218496  0.123171  0.116929
# Fresh milk      0.237583  0.198672  0.177698
# Goat meat       0.117064  0.110272  0.150778
# Ground nut      0.115567  0.106321  0.067263
# Irish potato    0.003965  0.067264  0.175748
# Maize           0.100274  0.184362  0.278685
# Mangos          0.125663  0.137754  0.416907
# Matoke          0.132916  0.111327  0.387687
# Millet          0.100629  0.114768  0.307190
# Onions          0.107144  0.077408  0.102898
# Oranges         0.141139  0.206122  0.090684
# Other Alcohol   0.317443  0.187771  0.029175
# Other Fruit     0.132778  0.176914  0.222251
# Other Tobacco   0.022822  0.199866 -0.125472
# Other Veg.      0.069908  0.080657  0.154084
# Other foods     0.146569 -0.132444 -0.192751
# Passion fruit   0.185715  0.112572  0.157052
# Peas            0.113617  0.068878  0.233551
# Pork            0.170278  0.056648  0.121077
# Restaurant      0.250423  0.062644 -0.153136
# Rice            0.134596  0.067603  0.254179
# Salt            0.049703  0.066528  0.234881
# Sim sim         0.111060  0.136771  0.101226
# Soda            0.180070  0.103475  0.037477
# Sorghum        -0.193992 -0.186989  0.675464
# Sugar           0.135978  0.064919  0.213028
# Sweet Banana    0.122614  0.156308  0.307808
# Sweet Potatoes  0.085376  0.138271  0.302070
# Tea             0.176332  0.178783  0.047672
# Tomatoes        0.142857  0.065837  0.063487

# %% [markdown]
# The triple of paramters  (𝛼,𝛽,𝛿)  completely describes the demand system and the corresponding utility function (over the goods we observe).

# %% [markdown]
# ### Ceteris Paribus
#
# holding other things equal

# %% [markdown]
# We begin by setting up some benchmarks for prices and budgets, so
#     the things we don&rsquo;t want to change we can hold fixed.

# %%
### First year, first market, and some good.  Change if you wish! ###
my_t = r.coords['t'].data.flatten()[0]
my_m = r.coords['m'].data.flatten()[0]
my_i = r.coords['i'].data.flatten()[0]
#####################################################################

p = r.prices.sel(t=my_t,m=my_m,drop=True)
# phat = refernce prices for each good
phat = p.to_dataframe('i').dropna().squeeze()

ref_price = r.prices.sel(i=my_i,t=my_t,m=my_m)
P = np.linspace(ref_price/10,ref_price*5,50)

def my_prices(p0,p=phat,i=my_i):
    """
    Set price of good i to p0, holding remaining prices fixed at values in p.
    """
    p = p.copy()
    p.loc[i] = p0
    return p.squeeze()

# %%
my_t, my_m, my_i
# Out:
# ('2005-06', 'Uganda', 'Beans')

# %%
phat
# Out:
# i
# Beans                600.000000
# Beef                2500.000000
# Beer                2800.000000
# Bun                 1200.000000
# Butter, etc.        3200.000000
# Cassava              150.000000
# Cassava (flour)      333.333333
# Chicken             3000.000000
# Cigarettes          8000.000000
# Coffee               800.000000
# Cooking oil          454.545455
# Dodo                 100.000000
# Dried fish           700.000000
# Fresh fish          1000.000000
# Fresh milk           400.000000
# Ghee                4000.000000
# Goat meat           2500.000000
# Ground nut          1200.000000
# Infant formula      8000.000000
# Irish potato         250.000000
# Maize                600.000000
# Mangos                66.666667
# Matoke               250.000000
# Millet               500.000000
# Onions               800.000000
# Oranges              250.000000
# Other Alcohol        800.000000
# Other Fruit          225.000000
# Other Tobacco      20000.000000
# Other Veg.           200.000000
# Other drinks         333.333333
# Other meat          2000.000000
# Passion fruit       1000.000000
# Peas                 700.000000
# Pork                2000.000000
# Rice                1200.000000
# Salt                 500.000000
# Sim sim              800.000000
# Soda                1666.666667
# Sorghum              276.190476
# Sugar               1600.000000
# Sweet Potatoes       150.000000
# Tea                  800.000000
# Tomatoes             500.000000
# Name: i, dtype: float64

# %% [markdown]
# #### Plot Demand Schedule

# %%
xbar = r.get_predicted_expenditures().sum('i')
median_x = xbar.where(xbar>0).sel(t=my_t,m=my_m).median('j') # Budget (median household)
# Out:
# /opt/conda/lib/python3.8/site-packages/xarray/core/nputils.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Values for prices
my_i = "Beans"
ref_price = r.prices.sel(i=my_i,t=my_t,m=my_m)
P = np.linspace(ref_price/5,ref_price*5,50)

for x in [median_x*s for s in [.25,.5,1.,2,4]]:
    plt.plot([r.demands(x,my_prices(p0))[my_i] for p0 in P],P)

plt.xlabel(my_i)
plt.ylabel('Price of %s' % my_i)
# Out:
# Text(0, 0.5, 'Price of Beans')

# %% [markdown]
# ### Nutrient Demands

# %% [markdown]
# The nutrient value of food consumed by the household is just the
#    product of its diet and a food conversion table.  So let&rsquo;s write a
#    function that describes that product:

# %%
# Get FCT:
fct = read_sheets(URL[COUNTRY],
                  json_creds='../students.json',
                  sheet='FCT').set_index('i')
fct.columns.name='n'

def nutrient_demand(x,p):
    c = r.demands(x,p)
    fct0,c0 = fct.align(c,axis=0,join='inner')
    N = fct0.T@c0

    N = N.loc[~N.index.duplicated()]
    
    return N

# %%
fct
# Out:
# n                Energy  Protein  Fiber  Folate  Calcium  Carbohydrate   Iron  \
# i
# Beans              1060       65     50    1040      270           191   16.0
# Beef               2910      264      0      50       90             0   27.0
# Beer                430        5      0      60       40            35    0.0
# Bread              2660       76     20    1110     1510           506   37.0
# Bun                2660       76     20    1110     1510           506   37.0
# Cabbages            250       13     30     430      400            58    5.0
# Cassava            1600       14     20     270      160           381    3.0
# Cassava (flour)    3140       26     40     360      310           766   19.0
# Chapati            2750       91     20     240      860           557   14.0
# Chicken            1840      274      0      30      130             0    9.0
# Cooking oil        8840        0      0       0        0             0    0.0
# Dodo                230       25      0     850     2150            40   23.0
# Dried fish         1170      249      0      60     1020             0   12.0
# Eggs               1430      126      0     470      530             8   18.0
# Fresh fish          960      201      0     220      100             0    6.0
# Fresh milk          600       32      0      50     1130            45    0.0
# Ghee               8760        3      0       0       40             0    0.0
# Goat meat          1090      206      0      40      130             0   28.0
# Ground nut         2240       57     40     100       40           455   17.0
# Infant formula     4960      263      0     310     9120           384    5.0
# Irish potato        770       20     20     160      120           175    8.0
# Maize              3970      102     80     140       80           809   28.0
# Matoke             1220       13     20     220       30           319    6.0
# Millet             3740      109     90     500       70           721   29.0
# Onions              400       11     20     190      230            93    2.0
# Oranges             470        9     20     290      400           118    1.0
# Passion fruit       970       22    100      80      110           234   14.0
# Peas                810       54     50     650      250           145   15.0
# Pork               2000      195      0      40      190             0    8.0
# Rice               3600       66      0      50       90           793    8.0
# Sim sim            5730      177    118     970     9750           235  145.5
# Soda                480        0      0       0       50           123    1.0
# Sorghum            3390      113     60      80      240           746   42.0
# Sugar              3870        0      0       0       10          1000    0.0
# Sweet Banana       1220       13     20     220       30           319    6.0
# Sweet Potatoes     1170       22     40     150      410           274    8.0
# Tomatoes            180        9     10     150      100            39    3.0
# Wheat (flour)      3640      103     30     260      150           763   12.0
#
# n                Niacin  Riboflavin  Thiamin  Vitamin A  Vitamin B-12  \
# i
# Beans              2.86        0.49     0.87          0           0.0
# Beef              33.50        2.20     0.50          0          18.5
# Beer               5.10        0.30     0.10          0           0.2
# Bread             43.85        3.31     4.55          0           0.0
# Bun               43.85        3.31     4.55          0           0.0
# Cabbages           2.34        0.40     0.61         50           0.0
# Cassava            8.54        0.48     0.87         10           0.0
# Cassava (flour)   14.00        0.50     3.10         70           0.0
# Chapati           21.42        0.97     2.67          0           0.0
# Chicken           78.07        1.15     0.41        250           2.1
# Cooking oil        0.00        0.00     0.00          0           0.0
# Dodo               6.58        1.58     0.27       1460           0.0
# Dried fish        19.00        1.20     0.80        100          22.0
# Eggs               0.70        4.78     0.69       1400          12.9
# Fresh fish        37.08        0.60     0.37          0          14.2
# Fresh milk         1.07        1.83     0.44        280           4.4
# Ghee               0.03        0.05     0.01       8400           0.1
# Goat meat         35.63        4.41     0.61          0           7.5
# Ground nut        21.09        1.16     2.12         60           0.0
# Infant formula     5.17       10.85     1.98       1930          26.0
# Irish potato      10.54        0.32     0.80          0           0.0
# Maize             35.52        1.97     3.35        110           0.0
# Matoke             6.86        0.54     0.52        560           0.0
# Millet            28.01        2.73     2.29          0           0.0
# Onions             1.20        0.30     0.50          0           0.0
# Oranges            2.82        0.40     0.83        110           0.0
# Passion fruit     12.00        1.17     0.00        480           0.0
# Peas              20.90        1.32     2.66        380           0.0
# Pork              42.66        2.25     4.90         20           0.0
# Rice              14.40        0.43     0.49          0           0.0
# Sim sim           45.20        2.50     7.90          0           0.0
# Soda               0.00        0.00     0.00          0           0.0
# Sorghum           17.56        1.35     1.30          0           0.0
# Sugar              0.00        0.19     0.00          0           0.0
# Sweet Banana       6.86        0.54     0.52        560           0.0
# Sweet Potatoes     7.61        0.83     1.07          0           0.0
# Tomatoes           5.94        0.19     0.37        420           0.0
# Wheat (flour)     12.50        0.40     1.20          0           0.0
#
# n                Vitamin B-6  Vitamin C  Zinc
# i
# Beans                   0.73         14   7.0
# Beef                    1.70          0  60.0
# Beer                    0.50          0   0.0
# Bread                   0.84          0   7.0
# Bun                     0.84          0   7.0
# Cabbages                1.24        366   2.0
# Cassava                 0.88        206   3.0
# Cassava (flour)         7.00        720   7.0
# Chapati                 0.34          0   8.0
# Chicken                 2.90          0  10.0
# Cooking oil             0.00          0   0.0
# Dodo                    1.92        433   9.0
# Dried fish              1.40         17  14.0
# Eggs                    1.43          0  11.0
# Fresh fish              1.46          0   3.0
# Fresh milk              0.36          0   4.0
# Ghee                    0.01          0   0.0
# Goat meat               1.30          0  40.0
# Ground nut              3.61          0  13.0
# Infant formula          1.81         69  33.0
# Irish potato            2.95        197   3.0
# Maize                   6.09          0  24.0
# Matoke                  2.99        184   1.0
# Millet                  1.90          0  17.0
# Onions                  1.20         74   2.0
# Oranges                 0.57        505   1.0
# Passion fruit           0.80        240   1.0
# Peas                    1.69        400  12.0
# Pork                    2.99          5  19.0
# Rice                    1.31          0  12.0
# Sim sim                 7.90          0  77.5
# Soda                    0.00          0   1.0
# Sorghum                 0.75          0  16.0
# Sugar                   0.00          0   0.0
# Sweet Banana            2.99        184   1.0
# Sweet Potatoes          2.85         33   4.0
# Tomatoes                0.80        127   2.0
# Wheat (flour)           0.44          0   7.0

# %%
fct[["Vitamin A", "Folate", "Calcium"]]
# Out:
# n                Vitamin A  Folate  Calcium
# i
# Beans                    0    1040      270
# Beef                     0      50       90
# Beer                     0      60       40
# Bread                    0    1110     1510
# Bun                      0    1110     1510
# Cabbages                50     430      400
# Cassava                 10     270      160
# Cassava (flour)         70     360      310
# Chapati                  0     240      860
# Chicken                250      30      130
# Cooking oil              0       0        0
# Dodo                  1460     850     2150
# Dried fish             100      60     1020
# Eggs                  1400     470      530
# Fresh fish               0     220      100
# Fresh milk             280      50     1130
# Ghee                  8400       0       40
# Goat meat                0      40      130
# Ground nut              60     100       40
# Infant formula        1930     310     9120
# Irish potato             0     160      120
# Maize                  110     140       80
# Matoke                 560     220       30
# Millet                   0     500       70
# Onions                   0     190      230
# Oranges                110     290      400
# Passion fruit          480      80      110
# Peas                   380     650      250
# Pork                    20      40      190
# Rice                     0      50       90
# Sim sim                  0     970     9750
# Soda                     0       0       50
# Sorghum                  0      80      240
# Sugar                    0       0       10
# Sweet Banana           560     220       30
# Sweet Potatoes           0     150      410
# Tomatoes               420     150      100
# Wheat (flour)            0     260      150

# %% [markdown]
# #### Plotting Nutrient Demand

# %%
import numpy as np
import pandas as pd

### If you're getting lots of not useful warnings you want to ignore
# import warnings
# warnings.filterwarnings('ignore',category=UserWarning)
####################################################################

X = np.linspace(median_x/5,median_x*5,50)

UseNutrients = ['Energy', 'Protein', 'Iron','Calcium']
#UseNutrients = fct.columns.tolist()

plt.plot(X,pd.concat({x:np.log(nutrient_demand(x,p))[UseNutrients] for x in X},axis=1).T)
plt.legend(UseNutrients)
plt.xlabel('log budget')
plt.ylabel('log nutrient')
# Out:
# Text(0, 0.5, 'log nutrient')

# %% [markdown]
# ### Nutritional requirements

# %% [markdown]
# Individuals have nutritional requirements established by nutrition
#  scientists.  Here we grab one such set of requirements:

# %%
# rdi = recommended daily intake
rdi = read_sheets(URL[COUNTRY],
                  json_creds='../students.json',
                  sheet='RDI').set_index('n').replace(np.nan,0)
rdi.columns.name = 'k'

rdi = rdi.replace('',0)
rdi
# Out:
# k             M 00-03  F 04-08  M 04-08  F 09-13  M 09-13  F 14-18  M 14-18  \
# n
# Energy         1000.0   1200.0   1400.0   1600.0   1800.0   1800.0   2200.0
# Protein          13.0     19.0     19.0     34.0     34.0     46.0     52.0
# Fiber            14.0     16.8     19.6     22.4     25.2     25.2     30.8
# Folate          150.0    200.0    200.0    300.0    300.0    400.0    400.0
# Calcium         700.0   1000.0   1000.0   1300.0   1300.0   1300.0   1300.0
# Carbohydrate    130.0    130.0    130.0    130.0    130.0    130.0    130.0
# Iron              7.0     10.0     10.0      8.0      8.0     15.0     11.0
# Magnesium        80.0    130.0    130.0    240.0    240.0    360.0    410.0
# Niacin            6.0      8.0      8.0     12.0     12.0     14.0     16.0
# Phosphorus      460.0    500.0    500.0   1250.0   1250.0   1250.0   1250.0
# Potassium      3000.0   3800.0   3800.0   4500.0   4500.0   4700.0   4700.0
# Riboflavin        0.5      0.6      0.6      0.9      0.9      1.0      1.3
# Thiamin           0.5      0.6      0.6      0.9      0.9      1.0      1.2
# Vitamin A       300.0    400.0    400.0    600.0    600.0    700.0    900.0
# Vitamin B-12      0.9      1.2      1.2      1.8      1.8      2.4      2.4
# Vitamin B-6       0.5      0.6      0.6      1.0      1.0      1.2      1.3
# Vitamin C        15.0     25.0     25.0     45.0     45.0     65.0     75.0
# Vitamin E         6.0      7.0      7.0     11.0     11.0     15.0     15.0
# Vitamin K        30.0     55.0     55.0     60.0     60.0     75.0     75.0
# Zinc              3.0      5.0      5.0      8.0      8.0      9.0     11.0
#
# k             F 19-30  M 19-30  F 31-50  M 31-50   F 51+   M 51+
# n
# Energy         2000.0   2400.0   1800.0   2200.0  1600.0  2000.0
# Protein          46.0     56.0     46.0     56.0    46.0    56.0
# Fiber            28.0     33.6     25.2     30.8    22.4    28.0
# Folate          400.0    400.0    400.0    400.0   400.0   400.0
# Calcium        1000.0   1000.0   1000.0   1000.0  1200.0  1000.0
# Carbohydrate    130.0    130.0    130.0    130.0   130.0   130.0
# Iron             18.0      8.0     18.0      8.0     8.0     8.0
# Magnesium       310.0    400.0    320.0    420.0   320.0   420.0
# Niacin           14.0     16.0     14.0     16.0    14.0    16.0
# Phosphorus      700.0    700.0    700.0    700.0   700.0   700.0
# Potassium      4700.0   4700.0   4700.0   4700.0  4700.0  4700.0
# Riboflavin        1.1      1.3      1.1      1.3     1.1     1.3
# Thiamin           1.1      1.2      1.1      1.2     1.1     1.2
# Vitamin A       700.0    900.0    700.0    900.0   700.0   900.0
# Vitamin B-12      2.4      2.4      2.4      2.4     2.4     2.4
# Vitamin B-6       1.3      1.3      1.3      1.3     1.5     1.7
# Vitamin C        75.0     90.0     75.0     90.0    75.0    90.0
# Vitamin E        15.0     15.0     15.0     15.0    15.0    15.0
# Vitamin K        90.0    120.0     90.0    120.0    90.0   120.0
# Zinc              8.0     11.0      8.0     11.0     8.0    11.0

# %% [markdown]
# #### Nutritional Needs of Households

# %% [markdown]
# Our data on demand and nutrients is at the *household* level; we
#     can&rsquo;t directly compare household level nutrition with individual
#     level requirements.  What we **can** do is add up minimum individual
#     requirements, and see whether household total exceed these.  This
#     isn&rsquo;t a guarantee that all individuals have adequate nutrition
#     (since the way food is allocated in the household might be quite
#     unequal, or unrelated to individual requirements), but it is
#     *necessary* if all individuals are to have adequate nutrition.
#
# For the average household, the number of different kinds of people
# can be computed by averaging over households:

# %%
# Find average household characteristics for reference period & place
zbar = r.z.sel(t=my_t,m=my_m,drop=True).mean('j').to_dataframe()
zbar
# Out:
#                   z
# k
# F 00-03    0.371236
# M 00-03    0.372197
# F 04-08    0.434017
# M 04-08    0.427611
# F 09-13    0.407431
# M 09-13    0.411595
# F 14-18    0.339526
# M 14-18    0.344331
# F 19-30    0.568546
# M 19-30    0.471172
# F 31-50    0.415759
# M 31-50    0.411275
# F 51+      0.187380
# M 51+      0.166560
# log HSize  1.475694

# %% [markdown]
# Now, the inner/dot/matrix product between `zbar` and the `rda`
#  DataFrame of requirements will give us minimum requirements for the
#  average household:

# %%
# This matrix product gives minimum nutrient requirements for average
# household in reference year & place
my_rdi,my_zbar = rdi.align(zbar.T,axis=1,join='inner')
hh_rdi = my_rdi@my_zbar.T

# But this is per *day*, while our data is per period (week for Uganda):
hh_rdi = hh_rdi*DAYS_PER_PERIOD[COUNTRY]
hh_rdi
# Out:
#                           z
# n
# Energy         61649.775785
# Protein         1366.551570
# Fiber            863.096861
# Folate         11449.775785
# Calcium        37338.565022
# Carbohydrate    4511.233184
# Iron             379.840807
# Magnesium       9815.201794
# Niacin           436.834081
# Phosphorus     28245.784753
# Potassium     152094.394619
# Riboflavin        34.159417
# Thiamin           33.184081
# Vitamin A      22817.040359
# Vitamin B-12      68.698655
# Vitamin B-6       37.577130
# Vitamin C       2059.125561
# Vitamin E        425.894619
# Vitamin K       2732.230942
# Zinc             278.130045

# %% [markdown]
# #### Nutritional Adequacy of Food Demands

# %% [markdown]
# Since we can trace out demands for nutrients as a function of $(x,p)$,
#  and we&rsquo;ve computed minimum nutritional requirements for the average
#  household, we can *normalize* nutritional intake to check the adequacy
#  of diet.

# %%
def nutrient_adequacy_ratio(x,p):
    return (nutrient_demand(x,p)/hh_rdi.T).squeeze()

# %% [markdown]
# Maybe select a few nutrients of particular interest&#x2026;

# %%
UseNutrients = ['Energy','Vitamin A','Zinc','Calcium', 'Folate', 'Vitamin C']
#UseNutrients = fct.columns.tolist()

# %%
plt.plot(X,pd.concat({x:np.log(nutrient_adequacy_ratio(x,p))[UseNutrients] for x in X},axis=1).T)
plt.legend(UseNutrients)
plt.xlabel('log budget')
plt.ylabel('log nutrient adequacy ratio')
plt.axhline(0)

# %% [markdown]
# As before, we can also vary relative prices. Here we trace out nutritional adequacy varying the price of a single good:

# %%
poorer_x = median_x/2

plt.plot(pd.concat({p0:np.log(nutrient_adequacy_ratio(poorer_x,my_prices(p0,i=my_i)))[UseNutrients] for p0 in P},axis=1).T,P)
plt.legend(UseNutrients)
plt.ylabel('Price')
plt.xlabel('log nutrient adequacy ratio')
plt.axvline(0)
plt.axhline(p.sel(i=my_i).values)

# %% [markdown]
# ### Simple Policy Experiments

# %% [markdown]
# Consider two policies:  First, changing income so that some proportion
#  of the population achieves nutritional adequacy.  Here choose quantile
#  we&rsquo;re interested in (e.g., a quantile of 0.5 is the median; a quantile
#  of 0.25 is the household at the 25th percentage point of the distribution).

# %%
# A quantile of 0.5 is the median.  Play with quantile value, or just assign.
xbar = r.get_predicted_expenditures().sel(t=my_t,m=my_m).sum('i')

# Drop households with /no/ predicted expenditures
xbar = xbar.where(xbar>0)

# make it median household budget
x0 = xbar.quantile(0.5,'j') # Budget (median household)
#x0 = 50

# Range of budgets to explore
X = np.linspace(x0/10,x0*5,50)
# Out:
# /opt/conda/lib/python3.8/site-packages/xarray/core/nputils.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)

# %% [markdown]
# ### Compensated Policy Experiments

# %%
# Marshallian = fixed budget -- trying to maximize utility subject to that

# Hicksian = fixed utility -- only involve substitution -- increase price --> also given a bit more income (to stay at same level of utility)

# %%
import matplotlib.pyplot as plt

#my_i = 'Milk'
my_i = 'Beans'
ref_price = r.prices.sel(i=my_i,t=my_t,m=my_m)
P = np.linspace(ref_price/10,ref_price*5,50)

U0 = r.indirect_utility(x0,p)

### If you're getting lots of not useful warnings you want to ignore
# import warnings
# warnings.filterwarnings('ignore',category=UserWarning)
####################################################################

plt.plot([r.demands(x0,my_prices(p0,i=my_i))[my_i] for p0 in P],P)
plt.plot([r.demands(U0,my_prices(p0,i=my_i),type="Hicksian")[my_i] for p0 in P],P)
plt.ylabel('Price')
plt.xlabel(my_i)
#plt.axhline(p.sel(i=my_i).values)
plt.legend(("Marshallian","Hicksian"))

# %%
# how much extra income i need in order to hold my utility constant at this higher price for the good
def compensating_variation(U0,p0,p1):
    x0 = r.expenditure(U0,p0)
    x1 = r.expenditure(U0,p1)

    return x1-x0

# if tax increases the price, how much extra revenue does the tax create?
def revenue(U0,p0,p1,type='Marshallian'):
    """(Un)Compensated revenue from taxes changing vector of prices from p0 to p1.

    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """
    
    dp = p1 - p0 # Change in prices

    c = r.demands(U0,p1,type=type)

    dp,c = dp.align(c,join='inner')

    return dp.T@c


def deadweight_loss(U0,p0,p1):
    """
    Deadweight loss of tax/subsidy scheme creating wedge in prices from p0 to p1.

    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """
    cv = compensating_variation(U0,p0,p1)

    return cv - revenue(U0,p0,p1,type='Hicksian') 
    
    
def compensated_nutrient_demand(U,p,z=None):
    c = r.demands(U,p,z=z,type='Hicksian')
    fct0,c0 = fct.align(c,axis=0,join='inner')
    N = fct0.T@c0

    return N

def compensated_nutrient_adequacy_ratio(U,p):
    return (compensated_nutrient_demand(U,p)/hh_rdi.T).squeeze()

# %% [markdown]
# Examine effects of price changes on *compensated* nutrient adequacy
# (i.e., a price increase is accompanied by additional income to keep
# utility constant).

# %%
## if flat: as price increases, Nutrients intake doesn't change very much
my_i = 'Matoke'

fig,ax2 = plt.subplots()
ax2.set_ylabel('log NAR')
ax2.plot(P,[np.log(compensated_nutrient_adequacy_ratio(U0,my_prices(p0,i=my_i))[UseNutrients]) for p0 in P])
ax2.legend(UseNutrients)
ax2.axhline(0)
ax2.set_xlabel("Price of %s" % my_i)
# Out:
# Text(0.5, 0, 'Price of Matoke')

# %% [markdown]
# Examine effects of price changes on revenue (if price change due to a
# tax or subsidy) and compensating variation.

# %%
fig, ax1 = plt.subplots()

ax1.plot(P,[compensating_variation(U0,phat,my_prices(p0,i=my_i)) for p0 in P])
ax1.set_xlabel("Price of %s" % my_i)
ax1.set_ylabel("Compensating Variation")

ax1.plot(P,[revenue(U0,phat,my_prices(p0,i=my_i),type='Hicksian') for p0 in P],'k')
ax1.legend(('Compensating Variation','Revenue'))
ax1.axhline(0)
ax1.axvline(phat.loc[my_i])

# %% [markdown]
# Differences between revenue and compensating variation is deadweight-loss:

# %%
fig, ax1 = plt.subplots()

ax1.plot(P,[deadweight_loss(U0,phat,my_prices(p0,i=my_i)) for p0 in P])
ax1.set_xlabel("Price of %s" % my_i)
ax1.set_ylabel("Deadweight Loss")
# Out:
# Text(0, 0.5, 'Deadweight Loss')
